# %% [markdown]
# <a href="https://colab.research.google.com/github/johanjun/Google_Machine_Learning_Bootcamp_KR_2021/blob/main/python_algorithm/7_Two_Sum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.
#
# You may assume that each input would have exactly one solution, and you may not use the same element twice.
#
# You can return the answer in any order.
#
#
# ```
# Example 1:
#
# Input: nums = [2,7,11,15], target = 9
# Output: [0,1]
# Output: Because nums[0] + nums[1] == 9, we return [0, 1].
# Example 2:
#
# Input: nums = [3,2,4], target = 6
# Output: [1,2]
# Example 3:
#
# Input: nums = [3,3], target = 6
# Output: [0,1]
# ```
# ```
# Constraints:
#
# 2 <= nums.length <= 104
# -109 <= nums[i] <= 109
# -109 <= target <= 109
# Only one valid answer exists.
# ```

# %%
nums = [3,2,4]
target = 6

# %%
for i, x in enumerate(nums):
  for j, y in enumerate(nums[i+1:]):
    print(i, j, x+y)
    if (x + y) == target:
      answer = [i, j+1]
      break
  else:
    continure
  break
# Out:
# 0 0 6

# %%
nums = [3,2,4]
target = 6

answer = []
pointer = 0
for i, x in enumerate(nums):
  for j, y in enumerate(nums[i+1:]):
    pointer = j+1
    print('i:', i,  "pointer:", pointer, "x:", x, "nums[pointer]:", nums[pointer])
    if nums[pointer] + x == target:
      print("if")
      answer = [i, pointer]
      break
    else:
      print("else")
      continue
      # pointer += 1
# Out:
# i: 0 pointer: 1 x: 3 nums[pointer]: 2
# else
# i: 0 pointer: 2 x: 3 nums[pointer]: 4
# else
# i: 1 pointer: 1 x: 2 nums[pointer]: 2
# else

# %%
nums = [2,7,11,15]
target = 9


answer=[]
for i,x in enumerate(nums):
  print("for1")
  for j,y in enumerate(nums):
    print("for2")
    print(i, x, j, y)
    if i != j:
      print("if1")
      if x+y == target:
        print("if2***")
        
        answer = [i, j]
        print(answer)
        break
  else:
    continue
  break
# Out:
# for1
# for2
# 0 2 0 2
# for2
# 0 2 1 7
# if1
# if2***
# [0, 1]

# %%
answer
# Out:
# []

# %%
class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        for i, x in enumerate(nums):
          for j, y in enumerate(nums[i+1:]):
            print(i, j, x+y)
            if (x + y) == target:
              answer = [i, j+1]
              break
          else:
            continue
          break  
        return answer

# %%
class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        answer = []
        pointer = 0
        for i, x in enumerate(nums):
          for j, y in enumerate(nums[i+1:]):
            pointer = j+1
            print('i:', i,  "pointer:", pointer, "x:", x, "nums[pointer]:", nums[pointer])
            if nums[pointer] + x == target:
              print("if")
              answer = [i, pointer]
              break
            else:
              print("else")
              continue
              # pointer += 1
          break
        return answer

# %%
class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
      nums = [3,2,4]
      target = 6
      answer=[]
      for i,x in enumerate(nums):
        for j,y in enumerate(nums):
          if i != j:
            if x+y == target:
              answer = [i, j]
              break
        else:
          continue
        break

# %%
from IPython.display import Image
Image('7. Two Sum.jpg')
