# %% [markdown]
# <a href="https://colab.research.google.com/github/johanjun/Google_Machine_Learning_Bootcamp_KR_2021/blob/main/python_algorithm/8_Trapping_Rain_Water.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Given n non-negative integers representing an elevation map where the width of each bar is 1, compute how much water it can trap after raining.

# %%
from IPython.display import Image
Image('rainwatertrap.png')

# %% [markdown]
# ```
# Example 1:
#
#
# Input: height = [0,1,0,2,1,0,1,3,2,1,2,1]
# Output: 6
# Explanation: The above elevation map (black section) is represented by array [0,1,0,2,1,0,1,3,2,1,2,1]. In this case, 6 units of rain water (blue section) are being trapped.
# Example 2:
#
# Input: height = [4,2,0,3,2,5]
# Output: 9
#  ```
# ```
# Constraints:
#
# n == height.length
# 1 <= n <= 2 * 104
# 0 <= height[i] <= 105
# ```

# %%
height = [0,1,0,2,1,0,1,3,2,1,2,1]

# %%
start = 0
wall = 0
end = -1
rain = 0
wall_idx = 0
for i, h in enumerate(height):
  print("i:", i, "h:", h)
  if i not in [0,1]:
    if h >= wall:
      if wall_idx != i:
        # wall = h
        wall_idx = i
        rain += (i-wall_idx-2) * wall - sum(height[wall_idx+1:i])
        print(f"if, h:{h}, wall:{wall}, wall_idx:{wall_idx}", f"rain:{rain}, dummies:{sum(height[wall_idx+1:i])}")
    # else:
    #   if i in [0, 1]:
    #     pass
    #   else:
    #     rain += (wall_idx-i-2) * wall - sum(height[wall_idx+1:i])
    #   print(f"else, rain:{rain}, dummies:{sum(height[wall_idx+1:i])}")
# Out:
# i: 0 h: 0
# i: 1 h: 1
# i: 2 h: 0
# if, h:0, wall:0, wall_idx:2 rain:0, dummies:0
# i: 3 h: 2
# if, h:2, wall:0, wall_idx:3 rain:0, dummies:0
# i: 4 h: 1
# if, h:1, wall:0, wall_idx:4 rain:0, dummies:0
# i: 5 h: 0
# if, h:0, wall:0, wall_idx:5 rain:0, dummies:0
# i: 6 h: 1
# if, h:1, wall:0, wall_idx:6 rain:0, dummies:0
# i: 7 h: 3
# if, h:3, wall:0, wall_idx:7 rain:0, dummies:0
# i: 8 h: 2
# if, h:2, wall:0, wall_idx:8 rain:0, dummies:0
# i: 9 h: 1
# if, h:1, wall:0, wall_idx:9 rain:0, dummies:0
# i: 10 h: 2
# if, h:2, wall:0, wall_idx:10 rain:0, dummies:0
# i: 11 h: 1
# if, h:1, wall:0, wall_idx:11 rain:0, dummies:0

# %%
rain
# Out:
# -10

# %%
#solution
class Solution:
    def trap(self, height: List[int]) -> int:
        if not height:
            return 0

        volume = 0
        left, right = 0, len(height) - 1
        left_max, right_max = height[left], height[right]

        while left < right:
            left_max, right_max = max(height[left], left_max), max(height[right], right_max)
            # 더 높은 쪽을 향해 투 포인터 이동
            if left_max <= right_max:
                volume += left_max - height[left]
                left += 1
            else:
                volume += right_max - height[right]
                right -= 1
        return volume

# %%
Image('8. Trapping Rain Water.jpg')
